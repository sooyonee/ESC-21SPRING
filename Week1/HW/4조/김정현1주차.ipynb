# %% [markdown]
# ## Week 1. Lab Code
#
# \* doc : https://docs.scipy.org/doc/scipy/reference/stats.html

# %%
import numpy as np
import scipy
import scipy.stats as st
from random import random
import inspect

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Peeking how to implement pdf function**

# %%
print(inspect.getsource(scipy.stats.norm._pdf))

print(inspect.getsource(scipy.stats.gamma._pdf))
# Out:
#     def _pdf(self, x):
#         # norm.pdf(x) = exp(-x**2/2)/sqrt(2*pi)
#         return _norm_pdf(x)
#
#     def _pdf(self, x, a):
#         # gamma.pdf(x, a) = x**(a-1) * exp(-x) / gamma(a)
#         return np.exp(self._logpdf(x, a))

# %% [markdown]
# ### Week likelihood, Uninformative prior

# %%
# Likelihood
n = 4
y = 3

def likelihood(theta, n, y):
    return theta**y*(1-theta)**(n-y)

# Prior
a0 = 1
b0 = 1
prior = st.beta(a=a0, b=b0)

# Posterior
post = st.beta(a=a0+n, b=b0+(n-y))

# plotting
thetas = np.linspace(0, 1, 300)
plt.figure(figsize=(8, 6))
plt.style.use('ggplot')
plt.plot(thetas, prior.pdf(thetas), label='Prior', c='blue')
plt.plot(thetas, likelihood(thetas, n, y), label='Likelihood', c='orange')
plt.plot(thetas, post.pdf(thetas), label='Posterior', c='red')
plt.xlim([-0.10, 1.10])
plt.xlabel(r'$\theta$', fontsize=14)
plt.ylabel('Density', fontsize=16)
plt.legend();

# %% [markdown]
# ### Weak Likelihood, Weak prior

# %%
# Likelihood
n = 4
y = 3

def likelihood(theta, n, y):
    return theta**y*(1-theta)**(n-y)

# Prior
a0 = 6
b0 = 4
prior = st.beta(a=a0, b=b0)

# Posterior
post = st.beta(a=a0+n, b=b0+(n-y))

# plotting
thetas = np.linspace(0, 1, 300)
plt.figure(figsize=(8, 6))
plt.style.use('ggplot')
plt.plot(thetas, prior.pdf(thetas), label='Prior', c='blue')
plt.plot(thetas, likelihood(thetas, n, y), label='Likelihood', c='orange')
plt.plot(thetas, post.pdf(thetas), label='Posterior', c='red')
plt.xlim([-0.10, 1.10])
plt.xlabel(r'$\theta$', fontsize=14)
plt.ylabel('Density', fontsize=16)
plt.legend();

# %% [markdown]
# ### Weak likelihood, Strong prior

# %%
# Likelihood
n = 4
y = 3

def likelihood(theta, n, y):
    return theta**y*(1-theta)**(n-y)

# Prior
a0 = 3000
b0 = 1000
prior = st.beta(a=a0, b=b0)

# Posterior
post = st.beta(a=a0+n, b=b0+(n-y))

# plotting
thetas = np.linspace(0, 1, 300)
plt.figure(figsize=(8, 6))
plt.style.use('ggplot')
plt.plot(thetas, prior.pdf(thetas), label='Prior', c='blue')
plt.plot(thetas, likelihood(thetas, n, y), label='Likelihood', c='orange')
plt.plot(thetas, post.pdf(thetas), label='Posterior', c='red')
plt.xlim([-0.10, 1.10])
plt.xlabel(r'$\theta$', fontsize=14)
plt.ylabel('Density', fontsize=16)
plt.legend();

# %% [markdown]
# ### Strong likelihood, Uninformative Prior

# %%
# Likelihood
n = 4000
y = 3000

def likelihood(theta, n, y):
    return theta**y*(1-theta)**(n-y)

# Prior
a0 = 1
b0 = 1
prior = st.beta(a=a0, b=b0)

# Posterior
post = st.beta(a=a0+n, b=b0+(n-y))

# plotting
thetas = np.linspace(0, 1, 300)
plt.figure(figsize=(8, 6))
plt.style.use('ggplot')
plt.plot(thetas, prior.pdf(thetas), label='Prior', c='blue')
plt.plot(thetas, likelihood(thetas, n, y), label='Likelihood', c='orange')
plt.plot(thetas, post.pdf(thetas), label='Posterior', c='red')
plt.xlim([-0.10, 1.10])
plt.xlabel(r'$\theta$', fontsize=14)
plt.ylabel('Density', fontsize=16)
plt.legend();

# %% [markdown]
# ### Strong likelihood, Weak Prior

# %%
# Likelihood
n = 4000
y = 3000

def likelihood(theta, n, y):
    return theta**y*(1-theta)**(n-y)

# Prior
a0 = 30
b0 = 10
prior = st.beta(a=a0, b=b0)

# Posterior
post = st.beta(a=a0+n, b=b0+(n-y))

# plotting
thetas = np.linspace(0, 1, 300)
plt.figure(figsize=(8, 6))
plt.style.use('ggplot')
plt.plot(thetas, prior.pdf(thetas), label='Prior', c='blue')
plt.plot(thetas, likelihood(thetas, n, y), label='Likelihood', c='orange')
plt.plot(thetas, post.pdf(thetas), label='Posterior', c='red')
plt.xlim([-0.10, 1.10])
plt.xlabel(r'$\theta$', fontsize=14)
plt.ylabel('Density', fontsize=16)
plt.legend();

# %% [markdown]
# ### Strong likelihood, Strong prior

# %%
# Likelihood
n = 4000
y = 3000

def likelihood(theta, n, y):
    return theta**y*(1-theta)**(n-y)

# Prior
a0 = 3000
b0 = 1000
prior = st.beta(a=a0, b=b0)

# Posterior
post = st.beta(a=a0+n, b=b0+(n-y))

# plotting
thetas = np.linspace(0, 1, 300)
plt.figure(figsize=(8, 6))
plt.style.use('ggplot')
plt.plot(thetas, prior.pdf(thetas), label='Prior', c='blue')
plt.plot(thetas, likelihood(thetas, n, y), label='Likelihood', c='orange')
plt.plot(thetas, post.pdf(thetas), label='Posterior', c='red')
plt.xlim([-0.10, 1.10])
plt.xlabel(r'$\theta$', fontsize=14)
plt.ylabel('Density', fontsize=16)
plt.legend();

# %% [markdown]
# ### 2
#
# <img src="1.jpeg">
# <img src="2.jpeg">

# %% [markdown]
# ### 3-(a)
#
# $\theta$ ~ $Beta(\alpha, \beta)$
#
# $E(\theta)$ = $\alpha$/$(\alpha+\beta)$ = 0.9
#
# $\alpha$ = 9$\beta$
#
# P(0.8<=$\theta$<=0.97)=0.7 as prior belief

# %%
for i in range(1,10):
    a0 = i*9
    b0 = i
    print("a0=",a0, "b0=",b0, st.beta.cdf(0.97,a0,b0)-st.beta.cdf(0.8,a0,b0))
# Out:
# a0= 9 b0= 1 0.626013330654565
# a0= 18 b0= 2 0.8071787111726657
# a0= 27 b0= 3 0.892715183397574
# a0= 36 b0= 4 0.9378685312699843
# a0= 45 b0= 5 0.9630476420328056
# a0= 54 b0= 6 0.9775813072560174
# a0= 63 b0= 7 0.9861808694298634
# a0= 72 b0= 8 0.991368387370736
# a0= 81 b0= 9 0.9945475074357272

# %% [markdown]
# $\theta$ ~ Beta(18,2)
#
# ### 3-(b)
#
# $\theta$|X ~ Beta($\alpha$ + n, $\beta$ + n - y))
#
# n=10, y=10
#
# $\therefore\theta|X$ ~ Beta(28, 2)

# %%
# Likelihood
n = 10
y = 10

def likelihood(theta, n, y):
    return theta**y*(1-theta)**(n-y)

# Prior
a0 = 18
b0 = 2
prior = st.beta(a=a0, b=b0)

# Posterior
post = st.beta(a=a0+n, b=b0+(n-y))

# plotting
thetas = np.linspace(0, 1, 300)
plt.figure(figsize=(8, 6))
plt.style.use('ggplot')
plt.plot(thetas, prior.pdf(thetas), label='Prior', c='blue')
plt.plot(thetas, likelihood(thetas, n, y), label='Likelihood', c='orange')
plt.plot(thetas, post.pdf(thetas), label='Posterior', c='red')
plt.xlim([-0.10, 1.10])
plt.xlabel(r'$\theta$', fontsize=14)
plt.ylabel('Density', fontsize=16)
plt.legend();

# %% [markdown]
# ### 3-(c)
#
# P($x_{new,post}|data) = \int_\theta P(x_{new}|\theta)P(\theta|data)d\theta$
#
# 다음환자가 생존할 확률:
#
# P($x_{new,post} | data) = \int_0^1 P(x_{new} = 1 | \theta)P(\theta|data)d\theta$ = $\int_0^1 \theta P(\theta|data)d\theta$ = E[$\theta$|data]

# %%
 st.beta(28,2).mean()
# Out:
# 0.9333333333333333

# %% [markdown]
# 다음 20명의 환자 중 2명 이상 사망할 확률
#
# $P($20명 중 2명 이상 사망$|data)$
#
# $=1-P($20명 중 20명 생존$|data)-P($20명 중 19명 생존$|data)$
#
# $=1-\int_{0}^{1}\theta^{20}P(\theta|data)d\theta-\int_{0}^{1}20\times\theta^{19}(1-\theta)P(\theta|data)d\theta$
