# %% [markdown]
# # Q1

# %% [markdown]
# ![Q1.png](data:image/png;base64,...)

# %% [markdown]
# # Q2

# %% [markdown]
# ![Q2_1.png](data:image/png;base64,...)

# %% [markdown]
# ![Q2_2.png](data:image/png;base64,...)
