# %% [markdown]
# # WEEK5 과제

# %%
from IPython.display import Image

# %% [markdown]
# ### 1번

# %%
Image("C:/Users/yujinjeong/Desktop/1.jpg")

# %%
Image("C:/Users/yujinjeong/Desktop/2.jpg")

# %% [markdown]
# ### 2번

# %%
Image("C:/Users/yujinjeong/Desktop/3.jpg")
