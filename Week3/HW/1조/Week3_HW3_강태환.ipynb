# %%
from IPython.display import Image

# %%
Image("C:/Users/rkdxo/Desktop/햑교/2021-1/ESC/week3/KakaoTalk_20210323_213855481.jpg")

# %%
Image("C:/Users/rkdxo/Desktop/햑교/2021-1/ESC/week3/KakaoTalk_20210323_213855481_01.jpg")

# %%
Image("C:/Users/rkdxo/Desktop/햑교/2021-1/ESC/week3/Q3.png")

# %%
Image("C:/Users/rkdxo/Desktop/햑교/2021-1/ESC/week3/Q3-1.png")

# %%
Image("C:/Users/rkdxo/Desktop/햑교/2021-1/ESC/week3/Q3-2.png")
