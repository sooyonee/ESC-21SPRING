# %% [markdown]
# ## 3주차 과제

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# R 실습

# %% [markdown]
# ### 코드

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 결과

# %% [markdown]
# ![image.png](attachment:image.png)
