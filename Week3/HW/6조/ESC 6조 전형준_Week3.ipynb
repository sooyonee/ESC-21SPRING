# %% [markdown]
# ### 문제 1번

# %% [markdown]
# BDA Chapter 2 Exercise 8

# %% [markdown]
# ![Pb1.jpg](attachment:Pb1.jpg)

# %% [markdown]
# ### 문제 2번

# %% [markdown]
# Two parameter models-Normal data with a conjugate prior distribution에서 수식의 marginal posterior distribution 유도해보기

# %% [markdown]
# ![Pb2.jpg](attachment:Pb2.jpg)

# %% [markdown]
# ### 문제 3번

# %% [markdown]
# R코드 시각화 따라해보기

# %% [markdown]
# ![Pb3_code.jpg](attachment:Pb3_code.jpg)

# %% [markdown]
# ![Pb3_picture.jpg](attachment:Pb3_picture.jpg)
